# %% [markdown]
# <a href="https://colab.research.google.com/github/vyphamhung10/khoa_luan/blob/master/price_prediction_single_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# -*- coding: utf-8 -*-
"""working.ipynb

Automatically generated by Colaboratory.

Original file is located at
    https://colab.research.google.com/drive/1llsccnklCzs7EZSELP6MVysncixaZnQR

## Notebook settings
"""
# region Import
# Data download
# Import basic
import csv
import math
import os
import warnings
# Init google drive
# from google.colab import drive
from datetime import datetime
from timeit import default_timer as timer

import numpy as np
import pandas as pd
# Plottool
import plotly.graph_objs as go
# IPython
from IPython.display import display
# Hyperopt bayesian optimization
from hyperopt import hp, Trials, tpe, fmin, STATUS_OK, partial
# Keras
from keras import Sequential
from keras import optimizers
from keras.activations import softmax
from keras.callbacks import EarlyStopping, ModelCheckpoint  
from keras.initializers import random_normal, Ones 
from keras.layers import LSTM, Dropout, Input
from keras.models import Model
import keras.backend as K
# SKLearn
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# endregion
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
try:
  from google.colab import drive
  IN_COLAB = True
except:
  IN_COLAB = False

current_timestamp = datetime.now().strftime('%d%m%Y_%H%M%S')
if not IN_COLAB:
    
    # region File mount and config
    # drive.mount('/content/gdrive', force_remount=True)
    root_dir = ""
    
    time_dir = os.path.join(root_dir, "result")
    time_dir = os.path.join(time_dir, current_timestamp)
    
    data_dir = root_dir + 'data'
    model_dir = os.path.join(time_dir, 'model')
    plot_dir = os.path.join(time_dir, 'plot')
    result_dir = os.path.join(time_dir, 'result')
    # Create folder if not exists
    
    if not os.path.exists(data_dir):
        os.makedirs(data_dir)
        
    if not os.path.exists(model_dir):
        os.makedirs(model_dir)
    
    if not os.path.exists(plot_dir):
        os.makedirs(plot_dir)
        
    if not os.path.exists(result_dir):
        os.makedirs(result_dir)
else:
    # region File mount and config
    drive.mount('/content/gdrive', force_remount=True)
    root_dir = "/content/gdrive/My Drive/stock"
    
    time_dir = os.path.join(root_dir, "result")
    
    data_dir = os.path.join(root_dir, "data")
    model_dir = os.path.join(time_dir, 'model')
    plot_dir = os.path.join(time_dir, 'plot')
    result_dir = os.path.join(time_dir, 'result')
    
pd.options.display.max_columns = 12
pd.options.display.max_rows = 24

# disable warnings in Anaconda
warnings.filterwarnings('ignore')

# endregion
# Out:
# Mounted at /content/gdrive

# %%
# region Data Loading
stock_name = '000001.SS'  # SSE Composite Index
# df_org = yf.download(stock_name, start="1991-01-01", end="2016-12-31", interval="1wk")
df_org = pd.read_csv(f'{data_dir}/{stock_name}.csv', parse_dates=['Date'])
df_org = df_org.sort_values('Date')
# df_org.to_csv(f'{base_dir}/{stock_name}.csv')
df_org.reset_index(inplace=True)
df_org = df_org[['Date', 'Close', 'Open', 'High', 'Low', 'Adj Close', 'Volume']]

# endregion

# %%
# region Data ploting
def plot_ohlc(df):
    trace = go.Ohlc(x=df['Date'],
                    open=df['Open'],
                    high=df['High'],
                    low=df['Low'],
                    close=df['Close'],
                    increasing=dict(line=dict(color='#58FA58')),
                    decreasing=dict(line=dict(color='#FA5858')))

    layout = {
        'title': f'{stock_name} Historical Price',
        'xaxis': {'title': 'Date',
                  'rangeslider': {'visible': False}},
        'yaxis': {'title': f'Price'}
    }

    data = [trace]

    fig = go.Figure(data=data, layout=layout)
    fig.write_html(os.path.join(plot_dir, '%s_ohlc.html' % (stock_name)), auto_open=False)


plot_ohlc(df_org)
# endregion

# %%
# region Create csv result file
# File to save first results
result_save_fname = os.path.join(result_dir, 'result_%s-%s.csv' % (stock_name, current_timestamp))
of_connection = open(result_save_fname, 'w')
writer = csv.writer(of_connection)
# Write the headers to the file
writer.writerow(['stock_name', 'year', 'loss', 'params', 'iteration', 'windows_size', 'train_time'])
of_connection.close()

# Create file to save bayer best
bayer_save_fname = os.path.join(result_dir, 'bayer_best_%s-%s.csv' % (stock_name, current_timestamp))
of_connection = open(bayer_save_fname, 'w')
writer = csv.writer(of_connection)
# Write the headers to the file
writer.writerow(['stock_name', 'year', 'params', 'model_save_location'])
of_connection.close()
# endregion

# %%
# region Sample data

df_org.sample(10)

# endregion
# Out:
#            Date        Close         Open         High          Low  \
# 190  1994-08-23   710.679993   714.609985   722.229980   705.710022
# 612  2002-09-24  1581.619995  1602.203003  1602.354004  1577.530029
# 1087 2011-11-08  2528.714111  2514.259033  2529.632080  2472.760986
# 1072 2011-07-26  2703.782959  2685.753906  2726.802002  2677.118896
# 912  2008-07-01  2792.396973  2743.164062  2801.533936  2566.528076
# 923  2008-09-16  2236.409912  2049.812988  2269.732910  1802.331055
# 674  2003-12-02  1436.662964  1437.239990  1462.072998  1424.348999
# 886  2008-01-01  5393.342773  5265.000000  5403.349121  5201.892090
# 1024 2010-08-24  2652.664062  2636.531982  2667.170898  2588.643066
# 483  2000-04-04  1826.061035  1795.161011  1831.853027  1746.302002
#
#         Adj Close  Volume
# 190    710.679993       0
# 612   1581.619995       0
# 1087  2528.714111  391400
# 1072  2703.782959  366000
# 912   2792.396973  283600
# 923   2236.409912  356800
# 674   1436.662964   87200
# 886   5393.342773  348000
# 1024  2652.664062  478000
# 483   1826.061035       0

# %%
# region Const
# Declare const
input_col = ['Close', 'Open', 'High', 'Low', 'Adj Close', 'Volume']
output_col = ['Close']
time_col = ['Date']

# Input dimension
input_dim = len(input_col)
# Output dimension
output_dim = len(output_col)

# Number of session to prediction as one time
prediction_size = 1
# For each time model is train, the first is display
sample_display_test_size = 5
# Max bayer iteration
bayer_max_evals = 100
max_windows_size = 8

# endregion

# %%
# region Declare model
# declare model
def softMaxAxis1(x):
    return softmax(x, axis=1)


def get_model(input_dim, window_size, output_dim, lstm_layer_count=5, drop_rate=0.2):
    model = Sequential()
    model.add(LSTM(units=100, input_shape=(window_size, input_dim), return_sequences=True))
    model.add(Dropout(rate=drop_rate))

    for i in range(lstm_layer_count - 2):
        model.add(LSTM(units=100, return_sequences=True))
        model.add(Dropout(rate=drop_rate))
    
    model.add(LSTM(output_dim, activation=softMaxAxis1))
    opt = optimizers.Adam(lr=0.05, beta_1=0.99, beta_2=0.999)
    model.compile(loss='MAE', optimizer='adam')
    
    return model


# endregion

# %%
# region Error metric
def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)

    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

def root_mean_square_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)

    return np.mean((y_true - y_pred) / y_true)


def relative_root_mean_square_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    res = (y_true - y_pred) / y_true
    res = np.power(res, 2)
    res = np.mean(res)
    res = math.sqrt(res)

    return res


# endregion

# %%
# region Data preprocessing
# reprocessing data
def next_window(df, i, windows_size, prediction_size, input_col, output_col, time_col):
    '''Generates the next data window from the given index location i'''
    window = df[i: i + windows_size + prediction_size]
    x = window[input_col][:-prediction_size]
    y = window[output_col][-prediction_size:]
    y_time = window[time_col][-prediction_size:]
    return x, y, y_time

def smooting_data(df, window_size):
    return df.ewm(span=window_size).mean()

def preprocessing_data(df, windows_size, padding_size ,prediction_size, input_col, output_col, time_col):
    '''
    Create x, y train data windows
    Warning: batch method, not generative, make sure you have enough memory to
    load data, otherwise use generate_training_window() method.
    '''


    data_x = []
    data_y = []
    data_y_time = []
    for i in range(len(df) - windows_size - prediction_size):
        x, y, y_time = next_window(df, i, windows_size, prediction_size, input_col, output_col, time_col)
        data_x.append(x.values)
        data_y.append(y.values)
        data_y_time.append(y_time)

    time = pd.concat(data_y_time)

    # Padding data to fit the model
    data_x = np.pad(data_x, ((0, 0), (0, padding_size), (0, 0)), 'constant', constant_values=0)
 
    return np.array(data_x), np.array(data_y), time.values


def split_train_test_data(X, y):
    X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.2, shuffle=False)

    return X_train, y_train, X_valid, y_valid


# endregion

# %%
# region Model train
# Trainning model
def train_model(model, X_train, y_train, X_valid, y_valid, stock_name, year, window_size):
    if not IN_COLAB:
        model_save_fname = os.path.join(model_dir, '%s-%s-w%d.h5' % (stock_name, year, window_size))
    else:
        model_save_fname = os.path.join(model_dir, '%s-%s-w%d-%s.h5' % (stock_name, year, window_size, datetime.now().strftime('%d%m%Y_%H%M%S')))
    callbacks = [
        EarlyStopping(monitor='val_loss', patience=100),
        ModelCheckpoint(filepath=model_save_fname, monitor='val_loss', save_best_only=True)
    ]
    history = model.fit(
        X_train,
        y_train,
        epochs=1000,
        batch_size=10000,
        validation_data=(X_valid, y_valid),
        verbose=1,
        callbacks=callbacks,
        shuffle=False)
    model.save(model_save_fname)
    
    return history


# endregion

# %%
# region Test model
def test_model(model, test_data, window_size, padding_size,prediction_size, input_col, output_col, time_col):
    X, y, time = preprocessing_data(test_data, window_size, padding_size, prediction_size, input_col, output_col, time_col)
    
    y_pred = model.predict(X)
    
    y_pred = np.repeat(y_pred, input_dim, axis=1)
    y_pred = scaler.inverse_transform(y_pred)[:, [0]]
    y_pred = pd.Series(y_pred.flatten())

    df_test_result = pd.DataFrame(time, columns=['Date'])
    df_test_result['Prediction'] = y_pred
    df_test_result.set_index('Date', inplace=True)

    return df_test_result


def plot_test_result(test_result, stock_name, year, window_size):
    # Plotly
    trace0 = go.Scatter(
        x=test_result.index,
        y=test_result['Close'],
        name='Thực tế',
        line=dict(
            color=('#5042f4'),
            width=2)
    )

    trace1 = go.Scatter(
        x=test_result.index,
        y=test_result['Prediction'],
        name='Dự đoán',
        line=dict(
            color=('#005b4e'),
            width=2,
            dash='dot'
        )  # dash options include 'dash', 'dot', and 'dashdot'
    )

    data = [trace0, trace1]

    # Edit the layout
    layout = dict(title='Biểu đồ dự đoán',
                  xaxis=dict(title='Date'),
                  yaxis=dict(title='Price'),
                  paper_bgcolor='#FFF9F5',
                  plot_bgcolor='#FFF9F5'
                  )

    fig = go.Figure(data=data, layout=layout)
    if not IN_COLAB:
        fig.write_html(os.path.join(plot_dir, '%s_%s_w%d.html' % (stock_name, year, window_size)), auto_open=False)
    else:
        fig.write_html(os.path.join(plot_dir, '%s_%s_w%d_%s.html' % (stock_name, year, window_size, datetime.now().strftime('%d%m%Y_%H%M%S'))), auto_open=False)
        
# endregion

# %%
# region Bayers
def objective(params, model, df):
    # Keep track of evals
    global ITERATION

    ITERATION += 1

    # Make sure windows_size is int
    windows_size = int(params['windows_size'])
    print(f'Window size is {windows_size}')

    start = timer()

    # Handle data
    # TODO: smoothing ddata
    # df[input_col] = smooting_data(df[input_col], windows_size)

    X, y, time = preprocessing_data(df, windows_size, max_windows_size - windows_size, prediction_size, input_col, output_col, time_col)
 
    # Reshape data
    y = y.reshape((y.shape[0], y.shape[1]))

    X_train, y_train, X_valid, y_valid = split_train_test_data(X, y)

    # Perform n_train
    history = train_model(model, X_train, y_train, X_valid, y_valid, stock_name, year, windows_size)

    run_time = timer() - start

    # Test generated loss
    test_result = test_model(model, df, windows_size, max_windows_size - windows_size,prediction_size, input_col, output_col, time_col)
    test_result = test_result.join(df_org.set_index('Date'))
    plot_test_result(test_result, stock_name, year, windows_size)

    score = model.evaluate(X, y, 10000, 1)
    print(f'Window size {windows_size} score = {score}')
    #mae = mean_absolute_error(test_result['Close'], test_result['Prediction'])
    #mse = mean_squared_error(test_result['Close'], test_result['Prediction'])
    #mape = mean_absolute_percentage_error(test_result['Close'], test_result['Prediction'])
    #rrmse = relative_root_mean_square_error(test_result['Close'], test_result['Prediction'])

    #print(f'{stock_name} prediction for {prediction_size} day ahead')
    #print(f'MAE = {mae}')
    #print(f'MSE = {mse}')
    #print(f'MAPE = {mape}')
    #print(f'RRMSE = {rrmse}')
    #loss = mape
    loss = score
    # write row
    of_connection = open(result_save_fname, 'a')
    writer = csv.writer(of_connection)
    writer.writerow([stock_name, year, loss, params, ITERATION, windows_size, run_time])
    of_connection.close()

    # Dictionary with information for evaluation
    return {'loss': loss, 'params': params, 'iteration': ITERATION, 'test_result': test_result,
            'train_time': run_time, 'status': STATUS_OK}

start_year = df_org['Date'].values[:1][0]
start_year = pd.to_datetime(start_year).year

end_year = df_org['Date'].values[-1:][0]
end_year = pd.to_datetime(end_year).year

windows_size_best = []
# Global variable
global ITERATION

for year in range(start_year, end_year + 1):
    df = df_org[df_org['Date'].dt.year == year].copy()

    # Data too small, skip
    if df.shape[0] < 10:
        continue

    scaler = MinMaxScaler(feature_range=(0, 2))
    scaled_cols = scaler.fit_transform(df[input_col])
    df[input_col] = scaled_cols

    # Hyperparameter grid
    param_grid = {
        'windows_size': hp.choice('windows_size', np.arange(1, 8, dtype=int))
    }

    bayes_trials = Trials()

    # Create the algorithm
    bayes_algo = tpe.suggest

    ITERATION = 0

    # Paratial function, pass dataframe df and model
    model = get_model(input_dim, max_windows_size, output_dim)

    fmin_objective = partial(objective, model=model, df=df)

    bayes_best = fmin(fn=fmin_objective, space=param_grid,
                      algo=bayes_algo, trials=bayes_trials,
                      max_evals=bayer_max_evals)

    of_connection = open(bayer_save_fname, 'a')
    writer = csv.writer(of_connection)
    writer.writerow([stock_name, year, bayes_best, '123'])
    of_connection.close()

    windows_size_best.append([year, bayes_best])
# endregion
# Out:
# Window size is 4
#   0%|          | 0/100 [00:00<?, ?it/s, best loss: ?]WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3005: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Train on 38 samples, validate on 10 samples
# Epoch 1/1000
#   0%|          | 0/100 [00:04<?, ?it/s, best loss: ?]WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 38/38 [==============================]
#  - 4s 111ms/step - loss: 0.2918 - val_loss: 1.0702
#
# Epoch 2/1000
# 38/38 [==============================]
#  - 0s 3ms/step - loss: 0.2908 - val_loss: 1.0695
#
# Epoch 3/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.2893 - val_loss: 1.0679
#
# Epoch 4/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.2877 - val_loss: 1.0647
#
# Epoch 5/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.2855 - val_loss: 1.0590
#
# Epoch 6/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.2819 - val_loss: 1.0497
#
# Epoch 7/1000
# 38/38 [==============================]
#  - 0s 3ms/step - loss: 0.2783 - val_loss: 1.0348
#
# Epoch 8/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.2722 - val_loss: 1.0115
#
# Epoch 9/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.2655 - val_loss: 0.9764
#
# Epoch 10/1000
# 38/38 [==============================]
#  - 0s 3ms/step - loss: 0.2560 - val_loss: 0.9256
#
# Epoch 11/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.2410 - val_loss: 0.8559
#
# Epoch 12/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.2225 - val_loss: 0.7667
#
# Epoch 13/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.1992 - val_loss: 0.6629
#
# Epoch 14/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.1641 - val_loss: 0.5820
#
# Epoch 15/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.1315 - val_loss: 0.5516
#
# Epoch 16/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.1130 - val_loss: 0.5498
#
# Epoch 17/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.0901 - val_loss: 0.5498
#
# Epoch 18/1000
# 38/38 [==============================]
#  - 0s 5ms/step - loss: 0.0813 - val_loss: 0.5498
#
# Epoch 19/1000
# 38/38 [==============================]
#  - 0s 5ms/step - loss: 0.1013 - val_loss: 0.5498
#
# Epoch 20/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.1067 - val_loss: 0.5498
#
# Epoch 21/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.0949 - val_loss: 0.5498
#
# Epoch 22/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.1048 - val_loss: 0.5498
#
# Epoch 23/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.1046 - val_loss: 0.5498
#
# Epoch 24/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.0971 - val_loss: 0.5498
#
# Epoch 25/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.0966 - val_loss: 0.5498
#
# Epoch 26/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.0996 - val_loss: 0.5498
#
# Epoch 27/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.0929 - val_loss: 0.5498
#
# Epoch 28/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.0876 - val_loss: 0.5498
#
# Epoch 29/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.0834 - val_loss: 0.5498
#
# Epoch 30/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.0768 - val_loss: 0.5498
#
# Epoch 31/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.0761 - val_loss: 0.5539
#
# Epoch 32/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.0806 - val_loss: 0.5630
#
# Epoch 33/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.0792 - val_loss: 0.5797
#
# Epoch 34/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.0853 - val_loss: 0.6015
#
# Epoch 35/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.0783 - val_loss: 0.6206
#
# Epoch 36/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.0837 - val_loss: 0.6303
#
# Epoch 37/1000
# 38/38 [==============================]
#  - 0s 3ms/step - loss: 0.0865 - val_loss: 0.6327
#
# Epoch 38/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.0864 - val_loss: 0.6293
#
# Epoch 39/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.0826 - val_loss: 0.6215
#
# Epoch 40/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.0797 - val_loss: 0.6134
#
# Epoch 41/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.0785 - val_loss: 0.6054
#
# Epoch 42/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.0721 - val_loss: 0.5972
#
# Epoch 43/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.0778 - val_loss: 0.5927
#
# Epoch 44/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.0740 - val_loss: 0.5885
#
# Epoch 45/1000
# 38/38 [==============================]
#  - 0s 5ms/step - loss: 0.0779 - val_loss: 0.5910
#
# Epoch 46/1000
# 38/38 [==============================]
#  - 0s 5ms/step - loss: 0.0729 - val_loss: 0.6026
#
# Epoch 47/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.0752 - val_loss: 0.6158
#
# Epoch 48/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.0878 - val_loss: 0.6297
#
# Epoch 49/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.0794 - val_loss: 0.6407
#
# Epoch 50/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.0704 - val_loss: 0.6570
#
# Epoch 51/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.0711 - val_loss: 0.6748
#
# Epoch 52/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.0761 - val_loss: 0.6900
#
# Epoch 53/1000
# 38/38 [==============================]
#  - 0s 3ms/step - loss: 0.0787 - val_loss: 0.7068
#
# Epoch 54/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.0714 - val_loss: 0.7205
#
# Epoch 55/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.0725 - val_loss: 0.7300
#
# Epoch 56/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.0677 - val_loss: 0.7393
#
# Epoch 57/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.0700 - val_loss: 0.7483
#
# Epoch 58/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.0737 - val_loss: 0.7570
#
# Epoch 59/1000
# 38/38 [==============================]
#  - 0s 3ms/step - loss: 0.0691 - val_loss: 0.7653
#
# Epoch 60/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.0676 - val_loss: 0.7650
#
# Epoch 61/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.0704 - val_loss: 0.7572
#
# Epoch 62/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.0711 - val_loss: 0.7481
#
# Epoch 63/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.0632 - val_loss: 0.7372
#
# Epoch 64/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.0701 - val_loss: 0.7268
#
# Epoch 65/1000
# 38/38 [==============================]
#  - 0s 5ms/step - loss: 0.0675 - val_loss: 0.7179
#
# Epoch 66/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.0674 - val_loss: 0.7256
#
# Epoch 67/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.0636 - val_loss: 0.7472
#
# Epoch 68/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.0651 - val_loss: 0.7656
#
# Epoch 69/1000
# 38/38 [==============================]
#  - 0s 5ms/step - loss: 0.0689 - val_loss: 0.7735
#
# Epoch 70/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.0657 - val_loss: 0.7811
#
# Epoch 71/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.0608 - val_loss: 0.7859
#
# Epoch 72/1000
# 38/38 [==============================]
#  - 0s 3ms/step - loss: 0.0672 - val_loss: 0.7767
#
# Epoch 73/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.0673 - val_loss: 0.7690
#
# Epoch 74/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.0677 - val_loss: 0.7612
#
# Epoch 75/1000
# 38/38 [==============================]
#  - 0s 5ms/step - loss: 0.0710 - val_loss: 0.7593
#
# Epoch 76/1000
# 38/38 [==============================]
#  - 0s 5ms/step - loss: 0.0699 - val_loss: 0.7591
#
# Epoch 77/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.0643 - val_loss: 0.7662
#
# Epoch 78/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.0650 - val_loss: 0.7708
#
# Epoch 79/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.0661 - val_loss: 0.7709
#
# Epoch 80/1000
# 38/38 [==============================]
#  - 0s 5ms/step - loss: 0.0599 - val_loss: 0.7784
#
# Epoch 81/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.0616 - val_loss: 0.7722
#
# Epoch 82/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.0621 - val_loss: 0.7652
#
# Epoch 83/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.0587 - val_loss: 0.7698
#
# Epoch 84/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.0717 - val_loss: 0.7683
#
# Epoch 85/1000
# 38/38 [==============================]
#  - 0s 3ms/step - loss: 0.0709 - val_loss: 0.7706
#
# Epoch 86/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.0710 - val_loss: 0.7711
#
# Epoch 87/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.0625 - val_loss: 0.7679
#
# Epoch 88/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.0637 - val_loss: 0.7714
#
# Epoch 89/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.0679 - val_loss: 0.7731
#
# Epoch 90/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.0662 - val_loss: 0.7742
#
# Epoch 91/1000
# 38/38 [==============================]
#  - 0s 3ms/step - loss: 0.0612 - val_loss: 0.7797
#
# Epoch 92/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.0682 - val_loss: 0.7796
#
# Epoch 93/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.0607 - val_loss: 0.7799
#
# Epoch 94/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.0622 - val_loss: 0.7689
#
# Epoch 95/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.0662 - val_loss: 0.7587
#
# Epoch 96/1000
# 38/38 [==============================]
#  - 0s 3ms/step - loss: 0.0665 - val_loss: 0.7533
#
# Epoch 97/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.0706 - val_loss: 0.7476
#
# Epoch 98/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.0600 - val_loss: 0.7430
#
# Epoch 99/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.0651 - val_loss: 0.7411
#
# Epoch 100/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.0661 - val_loss: 0.7319
#
# Epoch 101/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.0639 - val_loss: 0.7286
#
# Epoch 102/1000
# 38/38 [==============================]
#  - 0s 3ms/step - loss: 0.0626 - val_loss: 0.7263
#
# Epoch 103/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.0627 - val_loss: 0.7306
#
# Epoch 104/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.0644 - val_loss: 0.7310
#
# Epoch 105/1000
# 38/38 [==============================]
#  - 0s 3ms/step - loss: 0.0684 - val_loss: 0.7349
#
# Epoch 106/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.0590 - val_loss: 0.7405
#
# Epoch 107/1000
# 38/38 [==============================]
#  - 0s 3ms/step - loss: 0.0661 - val_loss: 0.7485
#
# Epoch 108/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.0661 - val_loss: 0.7538
#
# Epoch 109/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.0611 - val_loss: 0.7552
#
# Epoch 110/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.0622 - val_loss: 0.7615
#
# Epoch 111/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.0622 - val_loss: 0.7549
#
# Epoch 112/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.0666 - val_loss: 0.7494
#
# Epoch 113/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.0639 - val_loss: 0.7376
#
# Epoch 114/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.0615 - val_loss: 0.7221
#
# Epoch 115/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.0595 - val_loss: 0.7013
#
# Epoch 116/1000
# 38/38 [==============================]
#  - 0s 4ms/step - loss: 0.0670 - val_loss: 0.6873
#
# 48/48 [==============================]
#  - 0s 668us/step
#
# Window size 4 score = 0.19135959446430206
# Window size is 1
# Train on 40 samples, validate on 11 samples
# Epoch 1/1000
# 40/40 [==============================]
#  - 0s 4ms/step - loss: 0.2327 - val_loss: 0.6818
#
# Epoch 2/1000
# 40/40 [==============================]
#  - 0s 4ms/step - loss: 0.2167 - val_loss: 0.6527
#
# Epoch 3/1000
# 40/40 [==============================]
#  - 0s 4ms/step - loss: 0.1857 - val_loss: 0.6205
#
# Epoch 4/1000
# 40/40 [==============================]
#  - 0s 4ms/step - loss: 0.1530 - val_loss: 0.5870
#
# Epoch 5/1000
# 40/40 [==============================]
#  - 0s 4ms/step - loss: 0.1187 - val_loss: 0.5545
#
# Epoch 6/1000
# 40/40 [==============================]
#  - 0s 4ms/step - loss: 0.0939 - val_loss: 0.5264
#
# Epoch 7/1000
# 40/40 [==============================]
#  - 0s 3ms/step - loss: 0.0832 - val_loss: 0.5086
#
# Epoch 8/1000
# 40/40 [==============================]
#  - 0s 3ms/step - loss: 0.0890 - val_loss: 0.5033
#
# Epoch 9/1000
# 40/40 [==============================]
#  - 0s 3ms/step - loss: 0.1117 - val_loss: 0.5107
#
# Epoch 10/1000
# 40/40 [==============================]
#  - 0s 3ms/step - loss: 0.1255 - val_loss: 0.5295
#
# Epoch 11/1000
# 40/40 [==============================]
#  - 0s 3ms/step - loss: 0.1184 - val_loss: 0.5592
#
# Epoch 12/1000
# 40/40 [==============================]
#  - 0s 4ms/step - loss: 0.0985 - val_loss: 0.5976
#
# Epoch 13/1000
# 40/40 [==============================]
#  - 0s 3ms/step - loss: 0.0766 - val_loss: 0.6398
#
# Epoch 14/1000
# 40/40 [==============================]
#  - 0s 3ms/step - loss: 0.0492 - val_loss: 0.6732
#
# Epoch 15/1000
# 40/40 [==============================]
#  - 0s 4ms/step - loss: 0.0546 - val_loss: 0.7004
#
# Epoch 16/1000
# 40/40 [==============================]
#  - 0s 3ms/step - loss: 0.0634 - val_loss: 0.7239
#
# Epoch 17/1000
# 40/40 [==============================]
#  - 0s 5ms/step - loss: 0.0764 - val_loss: 0.7423
#
# Epoch 18/1000
# 40/40 [==============================]
#  - 0s 4ms/step - loss: 0.0788 - val_loss: 0.7542
#
# Epoch 19/1000
# 40/40 [==============================]
#  - 0s 3ms/step - loss: 0.0740 - val_loss: 0.7622
#
# Epoch 20/1000
# 40/40 [==============================]
#  - 0s 3ms/step - loss: 0.0604 - val_loss: 0.7687
#
# Epoch 21/1000
# 40/40 [==============================]
#  - 0s 4ms/step - loss: 0.0499 - val_loss: 0.7696
#
# Epoch 22/1000
# 40/40 [==============================]
#  - 0s 4ms/step - loss: 0.0384 - val_loss: 0.7670
#
# Epoch 23/1000
# 40/40 [==============================]
#  - 0s 4ms/step - loss: 0.0507 - val_loss: 0.7542
#
# Epoch 24/1000
# 40/40 [==============================]
#  - 0s 3ms/step - loss: 0.0592 - val_loss: 0.7323
#
# Epoch 25/1000
# 40/40 [==============================]
#  - 0s 3ms/step - loss: 0.0559 - val_loss: 0.7101
#
# Epoch 26/1000
# 40/40 [==============================]
#  - 0s 3ms/step - loss: 0.0501 - val_loss: 0.6889
#
# Epoch 27/1000
# 40/40 [==============================]
#  - 0s 4ms/step - loss: 0.0428 - val_loss: 0.6682
#
# Epoch 28/1000
# 40/40 [==============================]
#  - 0s 5ms/step - loss: 0.0474 - val_loss: 0.6542
#
# Epoch 29/1000
# 40/40 [==============================]
#  - 0s 3ms/step - loss: 0.0450 - val_loss: 0.6433
#
# Epoch 30/1000
# 40/40 [==============================]
#  - 0s 4ms/step - loss: 0.0466 - val_loss: 0.6384
#
# Epoch 31/1000
# 40/40 [==============================]
#  - 0s 3ms/step - loss: 0.0557 - val_loss: 0.6413
#
# Epoch 32/1000
# 40/40 [==============================]
#  - 0s 4ms/step - loss: 0.0452 - val_loss: 0.6480
#
# Epoch 33/1000
# 40/40 [==============================]
#  - 0s 4ms/step - loss: 0.0355 - val_loss: 0.6575
#
# Epoch 34/1000
# 40/40 [==============================]
#  - 0s 4ms/step - loss: 0.0396 - val_loss: 0.6661
#
# Epoch 35/1000
# 40/40 [==============================]
#  - 0s 4ms/step - loss: 0.0408 - val_loss: 0.6723
#
# Epoch 36/1000
# 40/40 [==============================]
#  - 0s 3ms/step - loss: 0.0436 - val_loss: 0.6750
#
# Epoch 37/1000
# 40/40 [==============================]
#  - 0s 4ms/step - loss: 0.0482 - val_loss: 0.6749
#
# Epoch 38/1000
# 40/40 [==============================]
#  - 0s 5ms/step - loss: 0.0465 - val_loss: 0.6732
#
# Epoch 39/1000
# 40/40 [==============================]
#  - 0s 4ms/step - loss: 0.0483 - val_loss: 0.6693
#
# Epoch 40/1000
# 40/40 [==============================]
#  - 0s 4ms/step - loss: 0.0413 - val_loss: 0.6644
#
# Epoch 41/1000
# 40/40 [==============================]
#  - 0s 4ms/step - loss: 0.0370 - val_loss: 0.6597
#
# Epoch 42/1000
# 40/40 [==============================]
#  - 0s 4ms/step - loss: 0.0402 - val_loss: 0.6566
#
# Epoch 43/1000
# 40/40 [==============================]
#  - 0s 4ms/step - loss: 0.0381 - val_loss: 0.6567
#
# Epoch 44/1000
# 40/40 [==============================]
#  - 0s 4ms/step - loss: 0.0406 - val_loss: 0.6554
#
# Epoch 45/1000
# 40/40 [==============================]
#  - 0s 4ms/step - loss: 0.0369 - val_loss: 0.6563
#
# Epoch 46/1000
# 40/40 [==============================]
#  - 0s 3ms/step - loss: 0.0402 - val_loss: 0.6585
#
# Epoch 47/1000
# 40/40 [==============================]
#  - 0s 3ms/step - loss: 0.0415 - val_loss: 0.6608
#
# Epoch 48/1000
# 40/40 [==============================]
#  - 0s 3ms/step - loss: 0.0425 - val_loss: 0.6629
#
# Epoch 49/1000
# 40/40 [==============================]
#  - 0s 3ms/step - loss: 0.0423 - val_loss: 0.6634
#
# Epoch 50/1000
# 40/40 [==============================]
#  - 0s 3ms/step - loss: 0.0401 - val_loss: 0.6601
#
# Epoch 51/1000
# 40/40 [==============================]
#  - 0s 4ms/step - loss: 0.0375 - val_loss: 0.6532
#
# Epoch 52/1000
# 40/40 [==============================]
#  - 0s 3ms/step - loss: 0.0368 - val_loss: 0.6466
#
# Epoch 53/1000
# 40/40 [==============================]
#  - 0s 3ms/step - loss: 0.0392 - val_loss: 0.6436
#
# Epoch 54/1000
# 40/40 [==============================]
#  - 0s 3ms/step - loss: 0.0369 - val_loss: 0.6413
#
# Epoch 55/1000
# 40/40 [==============================]
#  - 0s 3ms/step - loss: 0.0414 - val_loss: 0.6406
#
# Epoch 56/1000
# 40/40 [==============================]
#  - 0s 3ms/step - loss: 0.0343 - val_loss: 0.6413
#
# Epoch 57/1000
# 40/40 [==============================]
#  - 0s 4ms/step - loss: 0.0380 - val_loss: 0.6430
#
# Epoch 58/1000
# 40/40 [==============================]
#  - 0s 4ms/step - loss: 0.0382 - val_loss: 0.6462
#
# Epoch 59/1000
# 40/40 [==============================]
#  - 0s 3ms/step - loss: 0.0375 - val_loss: 0.6496
#
# Epoch 60/1000
# 40/40 [==============================]
#  - 0s 3ms/step - loss: 0.0363 - val_loss: 0.6516
#
# Epoch 61/1000
# 40/40 [==============================]
#  - 0s 3ms/step - loss: 0.0346 - val_loss: 0.6523
#
# Epoch 62/1000
# 40/40 [==============================]
#  - 0s 3ms/step - loss: 0.0321 - val_loss: 0.6516
#
# Epoch 63/1000
# 40/40 [==============================]
#  - 0s 4ms/step - loss: 0.0317 - val_loss: 0.6507
#
# Epoch 64/1000
# 40/40 [==============================]
#  - 0s 4ms/step - loss: 0.0384 - val_loss: 0.6479
#
# Epoch 65/1000
# 40/40 [==============================]
#  - 0s 4ms/step - loss: 0.0366 - val_loss: 0.6457
#
# Epoch 66/1000
# 40/40 [==============================]
#  - 0s 3ms/step - loss: 0.0368 - val_loss: 0.6428
#
# Epoch 67/1000
# 40/40 [==============================]
#  - 0s 4ms/step - loss: 0.0351 - val_loss: 0.6379
#
# Epoch 68/1000
# 40/40 [==============================]
#  - 0s 4ms/step - loss: 0.0367 - val_loss: 0.6336
#
# Epoch 69/1000
# 40/40 [==============================]
#  - 0s 4ms/step - loss: 0.0376 - val_loss: 0.6308
#
# Epoch 70/1000
# 40/40 [==============================]
#  - 0s 3ms/step - loss: 0.0366 - val_loss: 0.6294
#
# Epoch 71/1000
# 40/40 [==============================]
#  - 0s 3ms/step - loss: 0.0328 - val_loss: 0.6292
#
# Epoch 72/1000
# 40/40 [==============================]
#  - 0s 3ms/step - loss: 0.0311 - val_loss: 0.6311
#
# Epoch 73/1000
# 40/40 [==============================]
#  - 0s 3ms/step - loss: 0.0358 - val_loss: 0.6351
#
# Epoch 74/1000
# 40/40 [==============================]
#  - 0s 4ms/step - loss: 0.0363 - val_loss: 0.6379
#
# Epoch 75/1000
# 40/40 [==============================]
#  - 0s 3ms/step - loss: 0.0395 - val_loss: 0.6397
#
# Epoch 76/1000
# 40/40 [==============================]
#  - 0s 3ms/step - loss: 0.0369 - val_loss: 0.6386
#
# Epoch 77/1000
# 40/40 [==============================]
#  - 0s 4ms/step - loss: 0.0375 - val_loss: 0.6373
#
# Epoch 78/1000
# 40/40 [==============================]
#  - 0s 4ms/step - loss: 0.0338 - val_loss: 0.6349
#
# Epoch 79/1000
# 40/40 [==============================]
#  - 0s 4ms/step - loss: 0.0386 - val_loss: 0.6316
#
# Epoch 80/1000
# 40/40 [==============================]
#  - 0s 4ms/step - loss: 0.0371 - val_loss: 0.6282
#
# Epoch 81/1000
# 40/40 [==============================]
#  - 0s 3ms/step - loss: 0.0358 - val_loss: 0.6239
#
# Epoch 82/1000
# 40/40 [==============================]
#  - 0s 3ms/step - loss: 0.0364 - val_loss: 0.6208
#
# Epoch 83/1000
# 40/40 [==============================]
#  - 0s 4ms/step - loss: 0.0360 - val_loss: 0.6211
#
# Epoch 84/1000
# 40/40 [==============================]
#  - 0s 4ms/step - loss: 0.0338 - val_loss: 0.6258
#
# Epoch 85/1000
# 40/40 [==============================]
#  - 0s 4ms/step - loss: 0.0405 - val_loss: 0.6313
#
# Epoch 86/1000
# 40/40 [==============================]
#  - 0s 4ms/step - loss: 0.0455 - val_loss: 0.6375
#
# Epoch 87/1000
# 40/40 [==============================]
#  - 0s 4ms/step - loss: 0.0372 - val_loss: 0.6443
#
# Epoch 88/1000
# 40/40 [==============================]
#  - 0s 4ms/step - loss: 0.0401 - val_loss: 0.6499
#
# Epoch 89/1000
# 40/40 [==============================]
#  - 0s 4ms/step - loss: 0.0360 - val_loss: 0.6512
#
# Epoch 90/1000
# 40/40 [==============================]
#  - 0s 4ms/step - loss: 0.0333 - val_loss: 0.6496
#
# Epoch 91/1000
# 40/40 [==============================]
#  - 0s 4ms/step - loss: 0.0379 - val_loss: 0.6461
#
# Epoch 92/1000
# 40/40 [==============================]
#  - 0s 4ms/step - loss: 0.0348 - val_loss: 0.6417
#
# Epoch 93/1000
# 40/40 [==============================]
#  - 0s 4ms/step - loss: 0.0354 - val_loss: 0.6380
#
# Epoch 94/1000
# 40/40 [==============================]
#  - 0s 4ms/step - loss: 0.0360 - val_loss: 0.6356
#
# Epoch 95/1000
# 40/40 [==============================]
#  - 0s 4ms/step - loss: 0.0349 - val_loss: 0.6339
#
# Epoch 96/1000
# 40/40 [==============================]
#  - 0s 4ms/step - loss: 0.0345 - val_loss: 0.6350
#
# Epoch 97/1000
# 40/40 [==============================]
#  - 0s 4ms/step - loss: 0.0365 - val_loss: 0.6373
#
# Epoch 98/1000
# 40/40 [==============================]
#  - 0s 3ms/step - loss: 0.0304 - val_loss: 0.6392
#
# Epoch 99/1000
# 40/40 [==============================]
#  - 0s 4ms/step - loss: 0.0375 - val_loss: 0.6405
#
# Epoch 100/1000
# 40/40 [==============================]
#  - 0s 4ms/step - loss: 0.0414 - val_loss: 0.6396
#
# Epoch 101/1000
# 40/40 [==============================]
#  - 0s 4ms/step - loss: 0.0353 - val_loss: 0.6379
#
# Epoch 102/1000
# 40/40 [==============================]
#  - 0s 5ms/step - loss: 0.0383 - val_loss: 0.6333
#
# Epoch 103/1000
# 40/40 [==============================]
#  - 0s 4ms/step - loss: 0.0322 - val_loss: 0.6275
#
# Epoch 104/1000
# 40/40 [==============================]
#  - 0s 4ms/step - loss: 0.0335 - val_loss: 0.6235
#
# Epoch 105/1000
# 40/40 [==============================]
#  - 0s 4ms/step - loss: 0.0376 - val_loss: 0.6212
#
# Epoch 106/1000
# 40/40 [==============================]
#  - 0s 4ms/step - loss: 0.0376 - val_loss: 0.6202
#
# Epoch 107/1000
# 40/40 [==============================]
#  - 0s 4ms/step - loss: 0.0400 - val_loss: 0.6195
#
# Epoch 108/1000
# 40/40 [==============================]
#  - 0s 3ms/step - loss: 0.0344 - val_loss: 0.6200
#
# 51/51 [==============================]
#  - 0s 644us/step
#
# Window size 1 score = 0.1577652543783188
# Window size is 3
# Train on 39 samples, validate on 10 samples
# Epoch 1/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.2393 - val_loss: 0.6785
#
# Epoch 2/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.2170 - val_loss: 0.6918
#
# Epoch 3/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.1831 - val_loss: 0.7047
#
# Epoch 4/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.1510 - val_loss: 0.7169
#
# Epoch 5/1000
# 39/39 [==============================]
#  - 0s 3ms/step - loss: 0.1143 - val_loss: 0.7284
#
# Epoch 6/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0932 - val_loss: 0.7382
#
# Epoch 7/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0853 - val_loss: 0.7448
#
# Epoch 8/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0868 - val_loss: 0.7471
#
# Epoch 9/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0976 - val_loss: 0.7431
#
# Epoch 10/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.1098 - val_loss: 0.7336
#
# Epoch 11/1000
# 39/39 [==============================]
#  - 0s 3ms/step - loss: 0.1143 - val_loss: 0.7192
#
# Epoch 12/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.1128 - val_loss: 0.7018
#
# Epoch 13/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.1030 - val_loss: 0.6828
#
# Epoch 14/1000
# 39/39 [==============================]
#  - 0s 5ms/step - loss: 0.0896 - val_loss: 0.6645
#
# Epoch 15/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0713 - val_loss: 0.6479
#
# Epoch 16/1000
# 39/39 [==============================]
#  - 0s 3ms/step - loss: 0.0595 - val_loss: 0.6328
#
# Epoch 17/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0613 - val_loss: 0.6219
#
# Epoch 18/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0657 - val_loss: 0.6200
#
# Epoch 19/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0756 - val_loss: 0.6271
#
# Epoch 20/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0795 - val_loss: 0.6412
#
# Epoch 21/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0766 - val_loss: 0.6567
#
# Epoch 22/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0625 - val_loss: 0.6732
#
# Epoch 23/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0584 - val_loss: 0.6896
#
# Epoch 24/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0474 - val_loss: 0.7073
#
# Epoch 25/1000
# 39/39 [==============================]
#  - 0s 3ms/step - loss: 0.0546 - val_loss: 0.7219
#
# Epoch 26/1000
# 39/39 [==============================]
#  - 0s 3ms/step - loss: 0.0597 - val_loss: 0.7349
#
# Epoch 27/1000
# 39/39 [==============================]
#  - 0s 3ms/step - loss: 0.0684 - val_loss: 0.7418
#
# Epoch 28/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0603 - val_loss: 0.7439
#
# Epoch 29/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0578 - val_loss: 0.7458
#
# Epoch 30/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0537 - val_loss: 0.7472
#
# Epoch 31/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0550 - val_loss: 0.7465
#
# Epoch 32/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0556 - val_loss: 0.7428
#
# Epoch 33/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0545 - val_loss: 0.7365
#
# Epoch 34/1000
# 39/39 [==============================]
#  - 0s 3ms/step - loss: 0.0585 - val_loss: 0.7310
#
# Epoch 35/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0531 - val_loss: 0.7207
#
# Epoch 36/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0598 - val_loss: 0.7084
#
# Epoch 37/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0553 - val_loss: 0.6998
#
# Epoch 38/1000
# 39/39 [==============================]
#  - 0s 3ms/step - loss: 0.0524 - val_loss: 0.6963
#
# Epoch 39/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0547 - val_loss: 0.6933
#
# Epoch 40/1000
# 39/39 [==============================]
#  - 0s 3ms/step - loss: 0.0534 - val_loss: 0.6932
#
# Epoch 41/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0509 - val_loss: 0.6906
#
# Epoch 42/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0536 - val_loss: 0.6889
#
# Epoch 43/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0571 - val_loss: 0.6908
#
# Epoch 44/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0506 - val_loss: 0.6952
#
# Epoch 45/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0549 - val_loss: 0.7020
#
# Epoch 46/1000
# 39/39 [==============================]
#  - 0s 3ms/step - loss: 0.0608 - val_loss: 0.7087
#
# Epoch 47/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0604 - val_loss: 0.7173
#
# Epoch 48/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0572 - val_loss: 0.7248
#
# Epoch 49/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0569 - val_loss: 0.7292
#
# Epoch 50/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0495 - val_loss: 0.7308
#
# Epoch 51/1000
# 39/39 [==============================]
#  - 0s 5ms/step - loss: 0.0580 - val_loss: 0.7278
#
# Epoch 52/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0530 - val_loss: 0.7233
#
# Epoch 53/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0602 - val_loss: 0.7194
#
# Epoch 54/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0566 - val_loss: 0.7161
#
# Epoch 55/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0560 - val_loss: 0.7162
#
# Epoch 56/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0522 - val_loss: 0.7165
#
# Epoch 57/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0604 - val_loss: 0.7162
#
# Epoch 58/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0534 - val_loss: 0.7136
#
# Epoch 59/1000
# 39/39 [==============================]
#  - 0s 3ms/step - loss: 0.0475 - val_loss: 0.7131
#
# Epoch 60/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0539 - val_loss: 0.7149
#
# Epoch 61/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0568 - val_loss: 0.7184
#
# Epoch 62/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0497 - val_loss: 0.7209
#
# Epoch 63/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0511 - val_loss: 0.7233
#
# Epoch 64/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0512 - val_loss: 0.7272
#
# Epoch 65/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0576 - val_loss: 0.7289
#
# Epoch 66/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0539 - val_loss: 0.7329
#
# Epoch 67/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0517 - val_loss: 0.7369
#
# Epoch 68/1000
# 39/39 [==============================]
#  - 0s 3ms/step - loss: 0.0591 - val_loss: 0.7382
#
# Epoch 69/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0557 - val_loss: 0.7403
#
# Epoch 70/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0556 - val_loss: 0.7398
#
# Epoch 71/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0537 - val_loss: 0.7395
#
# Epoch 72/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0485 - val_loss: 0.7365
#
# Epoch 73/1000
# 39/39 [==============================]
#  - 0s 3ms/step - loss: 0.0551 - val_loss: 0.7342
#
# Epoch 74/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0514 - val_loss: 0.7339
#
# Epoch 75/1000
# 39/39 [==============================]
#  - 0s 3ms/step - loss: 0.0553 - val_loss: 0.7327
#
# Epoch 76/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0524 - val_loss: 0.7281
#
# Epoch 77/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0511 - val_loss: 0.7242
#
# Epoch 78/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0606 - val_loss: 0.7228
#
# Epoch 79/1000
# 39/39 [==============================]
#  - 0s 5ms/step - loss: 0.0533 - val_loss: 0.7235
#
# Epoch 80/1000
# 39/39 [==============================]
#  - 0s 5ms/step - loss: 0.0536 - val_loss: 0.7243
#
# Epoch 81/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0502 - val_loss: 0.7222
#
# Epoch 82/1000
# 39/39 [==============================]
#  - 0s 3ms/step - loss: 0.0558 - val_loss: 0.7225
#
# Epoch 83/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0530 - val_loss: 0.7255
#
# Epoch 84/1000
# 39/39 [==============================]
#  - 0s 5ms/step - loss: 0.0505 - val_loss: 0.7257
#
# Epoch 85/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0517 - val_loss: 0.7258
#
# Epoch 86/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0502 - val_loss: 0.7263
#
# Epoch 87/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0484 - val_loss: 0.7282
#
# Epoch 88/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0553 - val_loss: 0.7320
#
# Epoch 89/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0456 - val_loss: 0.7370
#
# Epoch 90/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0494 - val_loss: 0.7419
#
# Epoch 91/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0533 - val_loss: 0.7466
#
# Epoch 92/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0499 - val_loss: 0.7481
#
# Epoch 93/1000
# 39/39 [==============================]
#  - 0s 3ms/step - loss: 0.0472 - val_loss: 0.7491
#
# Epoch 94/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0534 - val_loss: 0.7504
#
# Epoch 95/1000
# 39/39 [==============================]
#  - 0s 5ms/step - loss: 0.0531 - val_loss: 0.7520
#
# Epoch 96/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0534 - val_loss: 0.7535
#
# Epoch 97/1000
# 39/39 [==============================]
#  - 0s 5ms/step - loss: 0.0564 - val_loss: 0.7555
#
# Epoch 98/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0554 - val_loss: 0.7577
#
# Epoch 99/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0538 - val_loss: 0.7569
#
# Epoch 100/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0497 - val_loss: 0.7540
#
# Epoch 101/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0542 - val_loss: 0.7539
#
# Epoch 102/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0499 - val_loss: 0.7513
#
# Epoch 103/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0502 - val_loss: 0.7495
#
# Epoch 104/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0540 - val_loss: 0.7500
#
# Epoch 105/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0491 - val_loss: 0.7519
#
# Epoch 106/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0527 - val_loss: 0.7542
#
# Epoch 107/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0556 - val_loss: 0.7571
#
# Epoch 108/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0488 - val_loss: 0.7569
#
# Epoch 109/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0535 - val_loss: 0.7579
#
# Epoch 110/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0526 - val_loss: 0.7580
#
# Epoch 111/1000
# 39/39 [==============================]
#  - 0s 3ms/step - loss: 0.0565 - val_loss: 0.7548
#
# Epoch 112/1000
# 39/39 [==============================]
#  - 0s 3ms/step - loss: 0.0526 - val_loss: 0.7516
#
# Epoch 113/1000
# 39/39 [==============================]
#  - 0s 5ms/step - loss: 0.0550 - val_loss: 0.7515
#
# Epoch 114/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0496 - val_loss: 0.7568
#
# Epoch 115/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0533 - val_loss: 0.7657
#
# Epoch 116/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0539 - val_loss: 0.7756
#
# Epoch 117/1000
# 39/39 [==============================]
#  - 0s 3ms/step - loss: 0.0540 - val_loss: 0.7812
#
# Epoch 118/1000
# 39/39 [==============================]
#  - 0s 4ms/step - loss: 0.0520 - val_loss: 0.7794
#
# 49/49 [==============================]
#  - 0s 849us/step
#
# Window size 3 score = 0.19708304107189178
# Window size is 5
# Train on 37 samples, validate on 10 samples
# Epoch 1/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0972 - val_loss: 0.7770
#
# Epoch 2/1000
# 37/37 [==============================]
#  - 0s 3ms/step - loss: 0.0906 - val_loss: 0.7587
#
# Epoch 3/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0772 - val_loss: 0.7338
#
# Epoch 4/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0698 - val_loss: 0.7073
#
# Epoch 5/1000
# 37/37 [==============================]
#  - 0s 3ms/step - loss: 0.0754 - val_loss: 0.6844
#
# Epoch 6/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0836 - val_loss: 0.6675
#
# Epoch 7/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0872 - val_loss: 0.6521
#
# Epoch 8/1000
# 37/37 [==============================]
#  - 0s 3ms/step - loss: 0.0787 - val_loss: 0.6398
#
# Epoch 9/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0703 - val_loss: 0.6297
#
# Epoch 10/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0717 - val_loss: 0.6255
#
# Epoch 11/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0744 - val_loss: 0.6278
#
# Epoch 12/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0822 - val_loss: 0.6352
#
# Epoch 13/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0801 - val_loss: 0.6495
#
# Epoch 14/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0740 - val_loss: 0.6685
#
# Epoch 15/1000
# 37/37 [==============================]
#  - 0s 5ms/step - loss: 0.0636 - val_loss: 0.6899
#
# Epoch 16/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0619 - val_loss: 0.7107
#
# Epoch 17/1000
# 37/37 [==============================]
#  - 0s 3ms/step - loss: 0.0671 - val_loss: 0.7286
#
# Epoch 18/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0678 - val_loss: 0.7411
#
# Epoch 19/1000
# 37/37 [==============================]
#  - 0s 3ms/step - loss: 0.0740 - val_loss: 0.7493
#
# Epoch 20/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0631 - val_loss: 0.7536
#
# Epoch 21/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0619 - val_loss: 0.7510
#
# Epoch 22/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0613 - val_loss: 0.7423
#
# Epoch 23/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0648 - val_loss: 0.7281
#
# Epoch 24/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0582 - val_loss: 0.7115
#
# Epoch 25/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0632 - val_loss: 0.6962
#
# Epoch 26/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0606 - val_loss: 0.6822
#
# Epoch 27/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0499 - val_loss: 0.6713
#
# Epoch 28/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0550 - val_loss: 0.6613
#
# Epoch 29/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0544 - val_loss: 0.6586
#
# Epoch 30/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0503 - val_loss: 0.6558
#
# Epoch 31/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0521 - val_loss: 0.6554
#
# Epoch 32/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0538 - val_loss: 0.6550
#
# Epoch 33/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0517 - val_loss: 0.6566
#
# Epoch 34/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0557 - val_loss: 0.6618
#
# Epoch 35/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0598 - val_loss: 0.6711
#
# Epoch 36/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0552 - val_loss: 0.6820
#
# Epoch 37/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0557 - val_loss: 0.6937
#
# Epoch 38/1000
# 37/37 [==============================]
#  - 0s 5ms/step - loss: 0.0476 - val_loss: 0.7038
#
# Epoch 39/1000
# 37/37 [==============================]
#  - 0s 5ms/step - loss: 0.0584 - val_loss: 0.7102
#
# Epoch 40/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0499 - val_loss: 0.7161
#
# Epoch 41/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0471 - val_loss: 0.7208
#
# Epoch 42/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0532 - val_loss: 0.7223
#
# Epoch 43/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0561 - val_loss: 0.7213
#
# Epoch 44/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0498 - val_loss: 0.7181
#
# Epoch 45/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0516 - val_loss: 0.7161
#
# Epoch 46/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0517 - val_loss: 0.7108
#
# Epoch 47/1000
# 37/37 [==============================]
#  - 0s 5ms/step - loss: 0.0552 - val_loss: 0.7041
#
# Epoch 48/1000
# 37/37 [==============================]
#  - 0s 5ms/step - loss: 0.0510 - val_loss: 0.6979
#
# Epoch 49/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0534 - val_loss: 0.6905
#
# Epoch 50/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0505 - val_loss: 0.6856
#
# Epoch 51/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0441 - val_loss: 0.6820
#
# Epoch 52/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0471 - val_loss: 0.6817
#
# Epoch 53/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0443 - val_loss: 0.6823
#
# Epoch 54/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0407 - val_loss: 0.6807
#
# Epoch 55/1000
# 37/37 [==============================]
#  - 0s 5ms/step - loss: 0.0419 - val_loss: 0.6778
#
# Epoch 56/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0483 - val_loss: 0.6727
#
# Epoch 57/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0490 - val_loss: 0.6678
#
# Epoch 58/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0493 - val_loss: 0.6623
#
# Epoch 59/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0424 - val_loss: 0.6597
#
# Epoch 60/1000
# 37/37 [==============================]
#  - 0s 5ms/step - loss: 0.0413 - val_loss: 0.6568
#
# Epoch 61/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0437 - val_loss: 0.6570
#
# Epoch 62/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0436 - val_loss: 0.6568
#
# Epoch 63/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0484 - val_loss: 0.6558
#
# Epoch 64/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0475 - val_loss: 0.6529
#
# Epoch 65/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0519 - val_loss: 0.6508
#
# Epoch 66/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0422 - val_loss: 0.6510
#
# Epoch 67/1000
# 37/37 [==============================]
#  - 0s 5ms/step - loss: 0.0432 - val_loss: 0.6533
#
# Epoch 68/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0415 - val_loss: 0.6558
#
# Epoch 69/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0447 - val_loss: 0.6599
#
# Epoch 70/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0378 - val_loss: 0.6645
#
# Epoch 71/1000
# 37/37 [==============================]
#  - 0s 5ms/step - loss: 0.0440 - val_loss: 0.6673
#
# Epoch 72/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0406 - val_loss: 0.6675
#
# Epoch 73/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0516 - val_loss: 0.6676
#
# Epoch 74/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0469 - val_loss: 0.6671
#
# Epoch 75/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0466 - val_loss: 0.6662
#
# Epoch 76/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0482 - val_loss: 0.6643
#
# Epoch 77/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0486 - val_loss: 0.6632
#
# Epoch 78/1000
# 37/37 [==============================]
#  - 0s 5ms/step - loss: 0.0445 - val_loss: 0.6632
#
# Epoch 79/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0461 - val_loss: 0.6665
#
# Epoch 80/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0366 - val_loss: 0.6669
#
# Epoch 81/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0476 - val_loss: 0.6675
#
# Epoch 82/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0427 - val_loss: 0.6674
#
# Epoch 83/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0459 - val_loss: 0.6669
#
# Epoch 84/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0418 - val_loss: 0.6679
#
# Epoch 85/1000
# 37/37 [==============================]
#  - 0s 3ms/step - loss: 0.0444 - val_loss: 0.6707
#
# Epoch 86/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0410 - val_loss: 0.6714
#
# Epoch 87/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0424 - val_loss: 0.6705
#
# Epoch 88/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0456 - val_loss: 0.6669
#
# Epoch 89/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0407 - val_loss: 0.6602
#
# Epoch 90/1000
# 37/37 [==============================]
#  - 0s 5ms/step - loss: 0.0391 - val_loss: 0.6555
#
# Epoch 91/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0483 - val_loss: 0.6525
#
# Epoch 92/1000
# 37/37 [==============================]
#  - 0s 3ms/step - loss: 0.0496 - val_loss: 0.6509
#
# Epoch 93/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0459 - val_loss: 0.6525
#
# Epoch 94/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0441 - val_loss: 0.6565
#
# Epoch 95/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0372 - val_loss: 0.6601
#
# Epoch 96/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0454 - val_loss: 0.6612
#
# Epoch 97/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0532 - val_loss: 0.6600
#
# Epoch 98/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0467 - val_loss: 0.6562
#
# Epoch 99/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0359 - val_loss: 0.6523
#
# Epoch 100/1000
# ...
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0343 - val_loss: 0.5627
#
# Epoch 32/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0307 - val_loss: 0.5694
#
# Epoch 33/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0276 - val_loss: 0.5749
#
# Epoch 34/1000
# 37/37 [==============================]
#  - 0s 5ms/step - loss: 0.0303 - val_loss: 0.5770
#
# Epoch 35/1000
# 37/37 [==============================]
#  - 0s 5ms/step - loss: 0.0268 - val_loss: 0.5764
#
# Epoch 36/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0322 - val_loss: 0.5765
#
# Epoch 37/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0302 - val_loss: 0.5765
#
# Epoch 38/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0308 - val_loss: 0.5760
#
# Epoch 39/1000
# 37/37 [==============================]
#  - 0s 3ms/step - loss: 0.0243 - val_loss: 0.5786
#
# Epoch 40/1000
# 37/37 [==============================]
#  - 0s 5ms/step - loss: 0.0316 - val_loss: 0.5783
#
# Epoch 41/1000
# 37/37 [==============================]
#  - 0s 5ms/step - loss: 0.0320 - val_loss: 0.5764
#
# Epoch 42/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0293 - val_loss: 0.5731
#
# Epoch 43/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0311 - val_loss: 0.5703
#
# Epoch 44/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0267 - val_loss: 0.5679
#
# Epoch 45/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0249 - val_loss: 0.5651
#
# Epoch 46/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0262 - val_loss: 0.5626
#
# Epoch 47/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0237 - val_loss: 0.5614
#
# Epoch 48/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0249 - val_loss: 0.5601
#
# Epoch 49/1000
# 37/37 [==============================]
#  - 0s 3ms/step - loss: 0.0326 - val_loss: 0.5590
#
# Epoch 50/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0298 - val_loss: 0.5602
#
# Epoch 51/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0331 - val_loss: 0.5599
#
# Epoch 52/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0268 - val_loss: 0.5613
#
# Epoch 53/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0260 - val_loss: 0.5618
#
# Epoch 54/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0243 - val_loss: 0.5599
#
# Epoch 55/1000
# 37/37 [==============================]
#  - 0s 5ms/step - loss: 0.0220 - val_loss: 0.5580
#
# Epoch 56/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0277 - val_loss: 0.5581
#
# Epoch 57/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0238 - val_loss: 0.5583
#
# Epoch 58/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0247 - val_loss: 0.5588
#
# Epoch 59/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0214 - val_loss: 0.5596
#
# Epoch 60/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0321 - val_loss: 0.5588
#
# Epoch 61/1000
# 37/37 [==============================]
#  - 0s 3ms/step - loss: 0.0290 - val_loss: 0.5545
#
# Epoch 62/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0263 - val_loss: 0.5509
#
# Epoch 63/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0244 - val_loss: 0.5499
#
# Epoch 64/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0233 - val_loss: 0.5502
#
# Epoch 65/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0273 - val_loss: 0.5527
#
# Epoch 66/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0266 - val_loss: 0.5539
#
# Epoch 67/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0227 - val_loss: 0.5540
#
# Epoch 68/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0243 - val_loss: 0.5536
#
# Epoch 69/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0259 - val_loss: 0.5555
#
# Epoch 70/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0265 - val_loss: 0.5545
#
# Epoch 71/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0262 - val_loss: 0.5538
#
# Epoch 72/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0239 - val_loss: 0.5527
#
# Epoch 73/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0266 - val_loss: 0.5516
#
# Epoch 74/1000
# 37/37 [==============================]
#  - 0s 3ms/step - loss: 0.0259 - val_loss: 0.5510
#
# Epoch 75/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0209 - val_loss: 0.5510
#
# Epoch 76/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0241 - val_loss: 0.5540
#
# Epoch 77/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0246 - val_loss: 0.5552
#
# Epoch 78/1000
# 37/37 [==============================]
#  - 0s 3ms/step - loss: 0.0318 - val_loss: 0.5546
#
# Epoch 79/1000
# 37/37 [==============================]
#  - 0s 3ms/step - loss: 0.0232 - val_loss: 0.5524
#
# Epoch 80/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0216 - val_loss: 0.5499
#
# Epoch 81/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0227 - val_loss: 0.5498
#
# Epoch 82/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0299 - val_loss: 0.5498
#
# Epoch 83/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0315 - val_loss: 0.5498
#
# Epoch 84/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0270 - val_loss: 0.5498
#
# Epoch 85/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0267 - val_loss: 0.5507
#
# Epoch 86/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0286 - val_loss: 0.5524
#
# Epoch 87/1000
# 37/37 [==============================]
#  - 0s 5ms/step - loss: 0.0188 - val_loss: 0.5551
#
# Epoch 88/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0250 - val_loss: 0.5560
#
# Epoch 89/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0301 - val_loss: 0.5541
#
# Epoch 90/1000
# 37/37 [==============================]
#  - 0s 5ms/step - loss: 0.0257 - val_loss: 0.5516
#
# Epoch 91/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0248 - val_loss: 0.5502
#
# Epoch 92/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0281 - val_loss: 0.5499
#
# Epoch 93/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0275 - val_loss: 0.5498
#
# Epoch 94/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0246 - val_loss: 0.5498
#
# Epoch 95/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0246 - val_loss: 0.5499
#
# Epoch 96/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0280 - val_loss: 0.5512
#
# Epoch 97/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0227 - val_loss: 0.5512
#
# Epoch 98/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0243 - val_loss: 0.5501
#
# Epoch 99/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0240 - val_loss: 0.5498
#
# Epoch 100/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0237 - val_loss: 0.5498
#
# Epoch 101/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0227 - val_loss: 0.5501
#
# Epoch 102/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0240 - val_loss: 0.5500
#
# Epoch 103/1000
# 37/37 [==============================]
#  - 0s 5ms/step - loss: 0.0208 - val_loss: 0.5500
#
# Epoch 104/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0221 - val_loss: 0.5498
#
# Epoch 105/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0213 - val_loss: 0.5498
#
# Epoch 106/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0216 - val_loss: 0.5498
#
# Epoch 107/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0243 - val_loss: 0.5498
#
# Epoch 108/1000
# 37/37 [==============================]
#  - 0s 4ms/step - loss: 0.0274 - val_loss: 0.5501
#
# 47/47 [==============================]
#  - 0s 850us/step
#
# Window size 5 score = 0.1292254626750946
# Window size is 7
# Train on 36 samples, validate on 9 samples
# Epoch 1/1000
# 36/36 [==============================]
#  - 0s 4ms/step - loss: 0.0778 - val_loss: 0.5982
#
# Epoch 2/1000
# 36/36 [==============================]
#  - 0s 5ms/step - loss: 0.0688 - val_loss: 0.5998
#
# Epoch 3/1000
# 36/36 [==============================]
#  - 0s 5ms/step - loss: 0.0454 - val_loss: 0.5999
#
# Epoch 4/1000
# 36/36 [==============================]
#  - 0s 4ms/step - loss: 0.0464 - val_loss: 0.5984
#
# Epoch 5/1000
# 36/36 [==============================]
#  - 0s 5ms/step - loss: 0.0448 - val_loss: 0.5978
#
# Epoch 6/1000
# 36/36 [==============================]
#  - 0s 5ms/step - loss: 0.0534 - val_loss: 0.5978
#
# Epoch 7/1000
# 36/36 [==============================]
#  - 0s 5ms/step - loss: 0.0476 - val_loss: 0.5978
#
# Epoch 8/1000
# 36/36 [==============================]
#  - 0s 5ms/step - loss: 0.0516 - val_loss: 0.5978
#
# Epoch 9/1000
# 36/36 [==============================]
#  - 0s 4ms/step - loss: 0.0402 - val_loss: 0.5978
#
# Epoch 10/1000
# 36/36 [==============================]
#  - 0s 4ms/step - loss: 0.0395 - val_loss: 0.5978
#
# Epoch 11/1000
# 36/36 [==============================]
#  - 0s 4ms/step - loss: 0.0450 - val_loss: 0.5978
#
# Epoch 12/1000
# 36/36 [==============================]
#  - 0s 4ms/step - loss: 0.0396 - val_loss: 0.5978
#
# Epoch 13/1000
# 36/36 [==============================]
#  - 0s 4ms/step - loss: 0.0331 - val_loss: 0.5978
#
# Epoch 14/1000
# 36/36 [==============================]
#  - 0s 5ms/step - loss: 0.0275 - val_loss: 0.5978
#
# Epoch 15/1000
# 36/36 [==============================]
#  - 0s 5ms/step - loss: 0.0312 - val_loss: 0.5978
#
# Epoch 16/1000
# 36/36 [==============================]
#  - 0s 4ms/step - loss: 0.0343 - val_loss: 0.5978
#
# Epoch 17/1000
# 36/36 [==============================]
#  - 0s 4ms/step - loss: 0.0334 - val_loss: 0.5978
#
# Epoch 18/1000
# 36/36 [==============================]
#  - 0s 4ms/step - loss: 0.0313 - val_loss: 0.5978
#
# Epoch 19/1000
# 36/36 [==============================]
#  - 0s 4ms/step - loss: 0.0306 - val_loss: 0.5978
#
# Epoch 20/1000
# 36/36 [==============================]
#  - 0s 5ms/step - loss: 0.0248 - val_loss: 0.5978
#
# Epoch 21/1000
# 36/36 [==============================]
#  - 0s 4ms/step - loss: 0.0346 - val_loss: 0.5978
#
# Epoch 22/1000
# 36/36 [==============================]
#  - 0s 4ms/step - loss: 0.0236 - val_loss: 0.5978
#
# Epoch 23/1000
# 36/36 [==============================]
#  - 0s 5ms/step - loss: 0.0312 - val_loss: 0.5978
#
# Epoch 24/1000
# 36/36 [==============================]
#  - 0s 4ms/step - loss: 0.0328 - val_loss: 0.5978
#
# Epoch 25/1000
# 36/36 [==============================]
#  - 0s 4ms/step - loss: 0.0244 - val_loss: 0.5978
#
# Epoch 26/1000
# 36/36 [==============================]
#  - 0s 4ms/step - loss: 0.0305 - val_loss: 0.5978
#
# Epoch 27/1000
# 36/36 [==============================]
#  - 0s 4ms/step - loss: 0.0297 - val_loss: 0.5978
#
# Epoch 28/1000
# 36/36 [==============================]
#  - 0s 4ms/step - loss: 0.0271 - val_loss: 0.5978
#
# Epoch 29/1000
# 36/36 [==============================]
#  - 0s 4ms/step - loss: 0.0344 - val_loss: 0.5978
#
# Epoch 30/1000
# 36/36 [==============================]
#  - 0s 4ms/step - loss: 0.0371 - val_loss: 0.5978
#
# Epoch 31/1000
# 36/36 [==============================]
#  - 0s 5ms/step - loss: 0.0324 - val_loss: 0.5978
#
# Epoch 32/1000
# 36/36 [==============================]
#  - 0s 4ms/step - loss: 0.0277 - val_loss: 0.5978
#
# Epoch 33/1000
# 36/36 [==============================]
#  - 0s 4ms/step - loss: 0.0285 - val_loss: 0.5978
#
# Epoch 34/1000
# 36/36 [==============================]
#  - 0s 4ms/step - loss: 0.0278 - val_loss: 0.5978
#
# Epoch 35/1000
# 36/36 [==============================]
#  - 0s 4ms/step - loss: 0.0258 - val_loss: 0.5978
#
# Epoch 36/1000
# 36/36 [==============================]
#  - 0s 4ms/step - loss: 0.0236 - val_loss: 0.5978
#
# Epoch 37/1000
# 36/36 [==============================]
#  - 0s 4ms/step - loss: 0.0238 - val_loss: 0.5978
#
# Epoch 38/1000
# 36/36 [==============================]
#  - 0s 4ms/step - loss: 0.0267 - val_loss: 0.5978
#
# Epoch 39/1000
# 36/36 [==============================]
#  - 0s 4ms/step - loss: 0.0257 - val_loss: 0.5978
#
# Epoch 40/1000
# 36/36 [==============================]
#  - 0s 4ms/step - loss: 0.0266 - val_loss: 0.5978
#
# Epoch 41/1000
# 36/36 [==============================]
#  - 0s 4ms/step - loss: 0.0236 - val_loss: 0.5978
#
# Epoch 42/1000
# 36/36 [==============================]
#  - 0s 4ms/step - loss: 0.0317 - val_loss: 0.5978
#
# Epoch 43/1000
# 36/36 [==============================]
#  - 0s 4ms/step - loss: 0.0270 - val_loss: 0.5978
#
# Epoch 44/1000
# 36/36 [==============================]
#  - 0s 4ms/step - loss: 0.0275 - val_loss: 0.5978
#
# Epoch 45/1000
# 36/36 [==============================]
#  - 0s 4ms/step - loss: 0.0234 - val_loss: 0.5978
#
# Epoch 46/1000
# 36/36 [==============================]
#  - 0s 4ms/step - loss: 0.0318 - val_loss: 0.5978
#
# Epoch 47/1000
# 36/36 [==============================]
#  - 0s 4ms/step - loss: 0.0248 - val_loss: 0.5978
#
# Epoch 48/1000
# 36/36 [==============================]
#  - 0s 4ms/step - loss: 0.0313 - val_loss: 0.5978
#
# Epoch 49/1000
# 36/36 [==============================]
#  - 0s 4ms/step - loss: 0.0204 - val_loss: 0.5978
#
# Epoch 50/1000
# 36/36 [==============================]
#  - 0s 4ms/step - loss: 0.0263 - val_loss: 0.5978
#
# Epoch 51/1000
# 36/36 [==============================]
#  - 0s 5ms/step - loss: 0.0276 - val_loss: 0.5978
#
# Epoch 52/1000
# 36/36 [==============================]
#  - 0s 5ms/step - loss: 0.0268 - val_loss: 0.5978
#
# Epoch 53/1000
# 36/36 [==============================]
#  - 0s 5ms/step - loss: 0.0294 - val_loss: 0.5978
#
# Epoch 54/1000
# 36/36 [==============================]
#  - 0s 5ms/step - loss: 0.0272 - val_loss: 0.5978
#
# Epoch 55/1000
# 36/36 [==============================]
#  - 0s 5ms/step - loss: 0.0267 - val_loss: 0.5978
#
# Epoch 56/1000
# 36/36 [==============================]
#  - 0s 5ms/step - loss: 0.0245 - val_loss: 0.5978
#
# Epoch 57/1000
# 36/36 [==============================]
#  - 0s 5ms/step - loss: 0.0262 - val_loss: 0.5978
#
# Epoch 58/1000
# 36/36 [==============================]
#  - 0s 5ms/step - loss: 0.0242 - val_loss: 0.5978
#
# Epoch 59/1000
# 36/36 [==============================]
#  - 0s 5ms/step - loss: 0.0279 - val_loss: 0.5978
#
# Epoch 60/1000
# 36/36 [==============================]
#  - 0s 5ms/step - loss: 0.0327 - val_loss: 0.5978
#
# Epoch 61/1000
# 36/36 [==============================]
#  - 0s 4ms/step - loss: 0.0267 - val_loss: 0.5978
#
# Epoch 62/1000
# 36/36 [==============================]
#  - 0s 4ms/step - loss: 0.0235 - val_loss: 0.5978
#
# Epoch 63/1000
# 36/36 [==============================]
#  - 0s 4ms/step - loss: 0.0209 - val_loss: 0.5978
#
# Epoch 64/1000
# 36/36 [==============================]
#  - 0s 4ms/step - loss: 0.0251 - val_loss: 0.5978
#
# Epoch 65/1000
# 36/36 [==============================]
#  - 0s 4ms/step - loss: 0.0208 - val_loss: 0.5978
#
# Epoch 66/1000
# 36/36 [==============================]
#  - 0s 4ms/step - loss: 0.0233 - val_loss: 0.5978
#
# Epoch 67/1000
# 36/36 [==============================]
#  - 0s 4ms/step - loss: 0.0276 - val_loss: 0.5978
#
# Epoch 68/1000
# 36/36 [==============================]
#  - 0s 4ms/step - loss: 0.0226 - val_loss: 0.5978
#
# Epoch 69/1000
# 36/36 [==============================]
#  - 0s 4ms/step - loss: 0.0249 - val_loss: 0.5978
#
# Epoch 70/1000
# 36/36 [==============================]
#  - 0s 4ms/step - loss: 0.0259 - val_loss: 0.5978
#
# Epoch 71/1000
# 36/36 [==============================]
#  - 0s 4ms/step - loss: 0.0277 - val_loss: 0.5978
#
# Epoch 72/1000
# 36/36 [==============================]
#  - 0s 5ms/step - loss: 0.0276 - val_loss: 0.5978
#
# Epoch 73/1000
# 36/36 [==============================]
#  - 0s 5ms/step - loss: 0.0275 - val_loss: 0.5978
#
# Epoch 74/1000
# 36/36 [==============================]
#  - 0s 4ms/step - loss: 0.0308 - val_loss: 0.5978
#
# Epoch 75/1000
# 36/36 [==============================]
#  - 0s 4ms/step - loss: 0.0295 - val_loss: 0.5978
#
# Epoch 76/1000
#  22%|██▏       | 22/100 [10:17<36:27, 28.04s/it, best loss: 0.1292254626750946]
